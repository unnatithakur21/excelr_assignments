# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
# conda install -c conda-forge mlxtend

# %%
book = pd.read_csv("C:/Users/krishna/Downloads/book.csv")

# %% [markdown]
# # Apriori algorithm

# %% [markdown]
# # Keeping minimum support = 10%

# %%
frequent_itemsets = apriori(book, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#     support                       itemsets
# 0    0.4230                     (ChildBks)
# 1    0.2475                     (YouthBks)
# 2    0.4310                      (CookBks)
# 3    0.2820                     (DoItYBks)
# 4    0.2145                       (RefBks)
# 5    0.2410                       (ArtBks)
# 6    0.2760                      (GeogBks)
# 7    0.1135                     (ItalCook)
# 8    0.1085                     (Florence)
# 9    0.1650           (YouthBks, ChildBks)
# 10   0.2560            (ChildBks, CookBks)
# 11   0.1840           (DoItYBks, ChildBks)
# 12   0.1515             (ChildBks, RefBks)
# 13   0.1625             (ChildBks, ArtBks)
# 14   0.1950            (ChildBks, GeogBks)
# 15   0.1620            (YouthBks, CookBks)
# 16   0.1155           (YouthBks, DoItYBks)
# 17   0.1010             (YouthBks, ArtBks)
# 18   0.1205            (YouthBks, GeogBks)
# 19   0.1875            (DoItYBks, CookBks)
# 20   0.1525              (CookBks, RefBks)
# ...

# %%
#Using Lift as Metric, keeping min value as 1
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#            antecedents         consequents  antecedent support  \
# 0           (YouthBks)          (ChildBks)              0.2475
# 1           (ChildBks)          (YouthBks)              0.4230
# 2           (ChildBks)           (CookBks)              0.4230
# 3            (CookBks)          (ChildBks)              0.4310
# 4           (DoItYBks)          (ChildBks)              0.2820
# ..                 ...                 ...                 ...
# 95   (ArtBks, GeogBks)           (CookBks)              0.1275
# 96  (CookBks, GeogBks)            (ArtBks)              0.1925
# 97            (ArtBks)  (CookBks, GeogBks)              0.2410
# 98           (CookBks)   (ArtBks, GeogBks)              0.4310
# 99           (GeogBks)   (CookBks, ArtBks)              0.2760
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.4230   0.1650    0.666667  1.576044  0.060308    1.731000
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(rules['support'], rules['confidence'],c=rules['lift'],cmap= 'summer',alpha=0.75)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using Confidence as Metric, keeping min value as 75%
rules2=association_rules(frequent_itemsets,metric="confidence",min_threshold=0.75)
rules2
# Out:
#              antecedents consequents  antecedent support  consequent support  \
# 0             (ItalCook)   (CookBks)              0.1135               0.431
# 1   (YouthBks, ChildBks)   (CookBks)              0.1650               0.431
# 2    (YouthBks, CookBks)  (ChildBks)              0.1620               0.423
# 3   (DoItYBks, ChildBks)   (CookBks)              0.1840               0.431
# 4    (DoItYBks, CookBks)  (ChildBks)              0.1875               0.423
# 5     (ChildBks, RefBks)   (CookBks)              0.1515               0.431
# 6      (CookBks, RefBks)  (ChildBks)              0.1525               0.423
# 7     (ChildBks, ArtBks)   (CookBks)              0.1625               0.431
# 8      (CookBks, ArtBks)  (ChildBks)              0.1670               0.423
# 9    (ChildBks, GeogBks)   (CookBks)              0.1950               0.431
# 10    (CookBks, GeogBks)  (ChildBks)              0.1925               0.423
# ...

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules2['support'], rules2['confidence'],c=rules2['lift'],cmap= 'summer',alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using Supprort as Metric, keeping min value as 15%
rules3 = association_rules(frequent_itemsets, metric="support", min_threshold=0.15)
rules3.sort_values('lift',ascending = False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 10  (ChildBks)   (GeogBks)              0.4230              0.2760   0.1950
# 11   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 6   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 7     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 17    (RefBks)   (CookBks)              0.2145              0.4310   0.1525
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
# 21   (GeogBks)   (CookBks)              0.2760              0.4310   0.1925
# 18    (ArtBks)   (CookBks)              0.2410              0.4310   0.1670
# 19   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 8   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# ...

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules3['support'], rules3['confidence'],c=rules3['lift'],cmap= 'summer',alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %% [markdown]
# # keeping min support = 15%

# %%
frequent_itemsets2=apriori(book,min_support=0.15,use_colnames=True)
frequent_itemsets2
# Out:
#     support              itemsets
# 0    0.4230            (ChildBks)
# 1    0.2475            (YouthBks)
# 2    0.4310             (CookBks)
# 3    0.2820            (DoItYBks)
# 4    0.2145              (RefBks)
# 5    0.2410              (ArtBks)
# 6    0.2760             (GeogBks)
# 7    0.1650  (YouthBks, ChildBks)
# 8    0.2560   (ChildBks, CookBks)
# 9    0.1840  (DoItYBks, ChildBks)
# 10   0.1515    (ChildBks, RefBks)
# 11   0.1625    (ChildBks, ArtBks)
# 12   0.1950   (ChildBks, GeogBks)
# 13   0.1620   (YouthBks, CookBks)
# 14   0.1875   (DoItYBks, CookBks)
# 15   0.1525     (CookBks, RefBks)
# 16   0.1670     (ArtBks, CookBks)
# 17   0.1925    (CookBks, GeogBks)

# %%
#Using Lift as Metric, keeping min value as 1 
rules4 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)
rules4.sort_values('lift',ascending = False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 10  (ChildBks)   (GeogBks)              0.4230              0.2760   0.1950
# 11   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 6   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 7     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 17    (RefBks)   (CookBks)              0.2145              0.4310   0.1525
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
# 21   (GeogBks)   (CookBks)              0.2760              0.4310   0.1925
# 18    (ArtBks)   (CookBks)              0.2410              0.4310   0.1670
# 19   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 8   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# ...

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules4['support'], rules4['confidence'],c=rules4['lift'],cmap= 'summer',alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using confidence as Metric, keeping min value as 0.6
rules5 = association_rules(frequent_itemsets2, metric="confidence", min_threshold=0.60)
rules5.sort_values('lift',ascending = False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 5    (GeogBks)  (ChildBks)              0.2760               0.423   0.1950
# 3     (RefBks)  (ChildBks)              0.2145               0.423   0.1515
# 8     (RefBks)   (CookBks)              0.2145               0.431   0.1525
# 10   (GeogBks)   (CookBks)              0.2760               0.431   0.1925
# 9     (ArtBks)   (CookBks)              0.2410               0.431   0.1670
# 4     (ArtBks)  (ChildBks)              0.2410               0.423   0.1625
# 0   (YouthBks)  (ChildBks)              0.2475               0.423   0.1650
# 7   (DoItYBks)   (CookBks)              0.2820               0.431   0.1875
# 2   (DoItYBks)  (ChildBks)              0.2820               0.423   0.1840
# 6   (YouthBks)   (CookBks)              0.2475               0.431   0.1620
# 1   (ChildBks)   (CookBks)              0.4230               0.431   0.2560
#
#     confidence      lift  leverage  conviction
# ...

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules5['support'], rules5['confidence'],c=rules5['lift'],cmap= 'summer',alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using Support as Metric, keeping min value as 0.15
rules6 = association_rules(frequent_itemsets2, metric="support", min_threshold=0.15)
rules6.sort_values('lift',ascending = False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 10  (ChildBks)   (GeogBks)              0.4230              0.2760   0.1950
# 11   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 6   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 7     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 17    (RefBks)   (CookBks)              0.2145              0.4310   0.1525
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
# 21   (GeogBks)   (CookBks)              0.2760              0.4310   0.1925
# 18    (ArtBks)   (CookBks)              0.2410              0.4310   0.1670
# 19   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 8   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# ...

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules6['support'], rules6['confidence'],c=rules6['lift'],cmap= 'summer',alpha=0.5)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %% [markdown]
# # keeping min support = 20%

# %%
frequent_itemsets3 = apriori(book, min_support=0.2, use_colnames=True)
frequent_itemsets3
# Out:
#    support             itemsets
# 0   0.4230           (ChildBks)
# 1   0.2475           (YouthBks)
# 2   0.4310            (CookBks)
# 3   0.2820           (DoItYBks)
# 4   0.2145             (RefBks)
# 5   0.2410             (ArtBks)
# 6   0.2760            (GeogBks)
# 7   0.2560  (ChildBks, CookBks)

# %%
#Using Lift as Metric, keeping min value as 0.1 
rules7 = association_rules(frequent_itemsets3, metric="lift", min_threshold=0.1)
rules7.sort_values('lift',ascending = False)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules7['support'], rules7['confidence'],c=rules7['lift'],cmap= 'summer',alpha=0.9)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using Confidence as Metric, keeping min value as 50%
rules8 = association_rules(frequent_itemsets3, metric="confidence", min_threshold=0.5)
rules8.sort_values('lift',ascending = False)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules8['support'], rules8['confidence'],c=rules8['lift'],cmap= 'summer',alpha=0.9)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
#Using Support as Metric, keeping min value as 20%
rules9 = association_rules(frequent_itemsets3, metric="support", min_threshold=0.2)
rules9.sort_values('lift',ascending = False)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.figure(figsize=(10,5))
import matplotlib.pyplot as plt
plt.scatter(rules9['support'], rules9['confidence'],c=rules9['lift'],cmap= 'summer',alpha=0.9)
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
cbar=plt.colorbar()
cbar.set_label('lift')

# %%
rules.sort_values('lift',ascending = False)
# Out:
#            antecedents          consequents  antecedent support  \
# 29           (CookBks)           (ItalCook)              0.4310
# 28          (ItalCook)            (CookBks)              0.1135
# 76  (ChildBks, ArtBks)            (GeogBks)              0.1625
# 81           (GeogBks)   (ChildBks, ArtBks)              0.2760
# 86            (ArtBks)  (DoItYBks, CookBks)              0.2410
# ..                 ...                  ...                 ...
# 4           (DoItYBks)           (ChildBks)              0.2820
# 12          (YouthBks)            (CookBks)              0.2475
# 13           (CookBks)           (YouthBks)              0.4310
# 3            (CookBks)           (ChildBks)              0.4310
# 2           (ChildBks)            (CookBks)              0.4230
#
#     consequent support  support  confidence      lift  leverage  conviction
# 29              0.1135   0.1135    0.263341  2.320186  0.064582    1.203406
# ...

# %%
rules4.sort_values('lift',ascending = False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 10  (ChildBks)   (GeogBks)              0.4230              0.2760   0.1950
# 11   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 6   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 7     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 17    (RefBks)   (CookBks)              0.2145              0.4310   0.1525
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
# 21   (GeogBks)   (CookBks)              0.2760              0.4310   0.1925
# 18    (ArtBks)   (CookBks)              0.2410              0.4310   0.1670
# 19   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 8   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# ...

# %%
rules7.sort_values('lift',ascending = False)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069
